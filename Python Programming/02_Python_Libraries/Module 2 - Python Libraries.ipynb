# %% [markdown]
# ## Libraries
#
# It is a set of function, modules, class which is used to perform a specific task

# %% [markdown]
# ## 1.Pandas Library
# - It is used for Data Analysis

# %%
import pandas as pd # Before installing pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas ## Installing pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd  # Alias

# %%
# If the data is in the another folder
coffee_sales = pd.read_csv(r"C:\Users\ravim\OneDrive\Documents\Materials\Power BI\Coffee Shop\Coffee Shop Raw Data\index_1.csv")
# Out:
#             date                 datetime cash_type                 card  \
# 0     2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1     2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002
# 2     2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002
# 3     2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003
# 4     2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004
# ...          ...                      ...       ...                  ...
# 3631  2025-03-23  2025-03-23 10:34:54.894      card  ANON-0000-0000-1158
# 3632  2025-03-23  2025-03-23 14:43:37.362      card  ANON-0000-0000-1315
# 3633  2025-03-23  2025-03-23 14:44:16.864      card  ANON-0000-0000-1315
# 3634  2025-03-23  2025-03-23 15:47:28.723      card  ANON-0000-0000-1316
# 3635  2025-03-23  2025-03-23 18:11:38.635      card  ANON-0000-0000-1275
#
#       money    coffee_name
# 0     38.70          Latte
# 1     38.70  Hot Chocolate
# ...

# %%
# If the data is in the same folder
coffee_sales = pd.read_csv("index_1.csv")
coffee_sales
# Out:
#             date                 datetime cash_type                 card  \
# 0     2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1     2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002
# 2     2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002
# 3     2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003
# 4     2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004
# ...          ...                      ...       ...                  ...
# 3631  2025-03-23  2025-03-23 10:34:54.894      card  ANON-0000-0000-1158
# 3632  2025-03-23  2025-03-23 14:43:37.362      card  ANON-0000-0000-1315
# 3633  2025-03-23  2025-03-23 14:44:16.864      card  ANON-0000-0000-1315
# 3634  2025-03-23  2025-03-23 15:47:28.723      card  ANON-0000-0000-1316
# 3635  2025-03-23  2025-03-23 18:11:38.635      card  ANON-0000-0000-1275
#
#       money    coffee_name
# 0     38.70          Latte
# 1     38.70  Hot Chocolate
# ...

# %% [markdown]
# ## 2.Numpy Library
# - Used Numerical Operations

# %%
import numpy as np

# %%
np.repeat(a = coffee_sales, repeats = 2, axis = 0 )
# Out:
# array([['2024-03-01', '2024-03-01 10:15:50.520', 'card',
#         'ANON-0000-0000-0001', 38.7, 'Latte'],
#        ['2024-03-01', '2024-03-01 10:15:50.520', 'card',
#         'ANON-0000-0000-0001', 38.7, 'Latte'],
#        ['2024-03-01', '2024-03-01 12:19:22.539', 'card',
#         'ANON-0000-0000-0002', 38.7, 'Hot Chocolate'],
#        ...,
#        ['2025-03-23', '2025-03-23 15:47:28.723', 'card',
#         'ANON-0000-0000-1316', 25.96, 'Americano'],
#        ['2025-03-23', '2025-03-23 18:11:38.635', 'card',
#         'ANON-0000-0000-1275', 35.76, 'Latte'],
#        ['2025-03-23', '2025-03-23 18:11:38.635', 'card',
#         'ANON-0000-0000-1275', 35.76, 'Latte']],
#       shape=(7272, 6), dtype=object)

# %%
coffee_shop_updated = pd.DataFrame(data = np.repeat(a = coffee_sales, repeats = 2, axis = 0 ))
coffee_shop_updated
# Out:
#                0                        1     2                    3      4  \
# 0     2024-03-01  2024-03-01 10:15:50.520  card  ANON-0000-0000-0001   38.7
# 1     2024-03-01  2024-03-01 10:15:50.520  card  ANON-0000-0000-0001   38.7
# 2     2024-03-01  2024-03-01 12:19:22.539  card  ANON-0000-0000-0002   38.7
# 3     2024-03-01  2024-03-01 12:19:22.539  card  ANON-0000-0000-0002   38.7
# 4     2024-03-01  2024-03-01 12:20:18.089  card  ANON-0000-0000-0002   38.7
# ...          ...                      ...   ...                  ...    ...
# 7267  2025-03-23  2025-03-23 14:44:16.864  card  ANON-0000-0000-1315  35.76
# 7268  2025-03-23  2025-03-23 15:47:28.723  card  ANON-0000-0000-1316  25.96
# 7269  2025-03-23  2025-03-23 15:47:28.723  card  ANON-0000-0000-1316  25.96
# 7270  2025-03-23  2025-03-23 18:11:38.635  card  ANON-0000-0000-1275  35.76
# 7271  2025-03-23  2025-03-23 18:11:38.635  card  ANON-0000-0000-1275  35.76
#
#                   5
# 0             Latte
# ...

# %% [markdown]
# ## 3.Matplotlib, Seaborn, Plotly Library
# - It is used for Data Visualization

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#      - -------------------------------------- 0.2/8.1 MB 6.3 MB/s eta 0:00:02
#      -- ------------------------------------- 0.5/8.1 MB 3.4 MB/s eta 0:00:03
#      --- ------------------------------------ 0.7/8.1 MB 3.5 MB/s eta 0:00:03
#      ---- ----------------------------------- 0.9/8.1 MB 3.3 MB/s eta 0:00:03
#      ---- ----------------------------------- 0.9/8.1 MB 2.5 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.0/8.1 MB 2.3 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.0/8.1 MB 2.3 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.0/8.1 MB 2.3 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.0/8.1 MB 1.4 MB/s eta 0:00:05
#      ----- ---------------------------------- 1.0/8.1 MB 1.4 MB/s eta 0:00:06
#      ----- ---------------------------------- 1.0/8.1 MB 1.4 MB/s eta 0:00:06
# ...

# %%
from matplotlib import pyplot as plt

# %%
plt.hist(x = coffee_sales.money)
# Out:
# (array([  36.,   59.,  222.,  463.,  435.,  400.,  490.,   66., 1287.,
#          178.]),
#  array([18.12 , 20.308, 22.496, 24.684, 26.872, 29.06 , 31.248, 33.436,
#         35.624, 37.812, 40.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## 2 Types of Data Types
# 1. Discerete - Countable, it will not have any units, you cant measure that
# 2. Continous - It will have units and it is measurable

# %%
pip install seaborn
# Out:
# ...
#      ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#      ---------------------- --------------- 174.1/294.9 kB 2.6 MB/s eta 0:00:01
#      -------------------------------------- 294.9/294.9 kB 2.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install plotly
# Out:
# ...
#      ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/9.9 MB 660.6 kB/s eta 0:00:15
#      ---------------------------------------- 0.1/9.9 MB 1.1 MB/s eta 0:00:10
#       --------------------------------------- 0.2/9.9 MB 1.5 MB/s eta 0:00:07
#      - -------------------------------------- 0.4/9.9 MB 2.1 MB/s eta 0:00:05
#      -- ------------------------------------- 0.5/9.9 MB 2.0 MB/s eta 0:00:05
#      -- ------------------------------------- 0.7/9.9 MB 2.3 MB/s eta 0:00:04
#      --- ------------------------------------ 0.8/9.9 MB 2.2 MB/s eta 0:00:05
#      ---- ----------------------------------- 1.0/9.9 MB 2.6 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.1/9.9 MB 2.6 MB/s eta 0:00:04
#      ----- ---------------------------------- 1.4/9.9 MB 2.7 MB/s eta 0:00:04
#      ------ --------------------------------- 1.5/9.9 MB 2.8 MB/s eta 0:00:04
# ...
